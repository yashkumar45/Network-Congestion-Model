# %%
# !pip install PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
download = drive.CreateFile({'id': '13bLNsDj7be1D4qbW_K-YLipj84mcw4-8'})
download.GetContentFile('trainu.zip')
# !unzip trainu.zip
# Out:
# ...
#     100% |████████████████████████████████| 993kB 20.8MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# ...
# Archive:  trainu.zip
#   inflating: trainu.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
train = pd.read_csv("trainu.csv")

# %%
######## factorizing the data ############


train["ran_vendor"] = pd.factorize(train.ran_vendor)[0]
#train["Congestion_Type"] = pd.factorize(train.Congestion_Type)[0]
#print(train["ran_vendor"])

# %%
train.drop(["cell_name","4G_rat","par_year","par_month","par_day","par_hour","par_min","subscriber_count","beam_direction","cell_range","tilt","ran_vendor"],axis=1,inplace = True)

# %%
train['Total_bytes']=train.web_browsing_total_bytes + train.video_total_bytes + train.social_ntwrking_bytes + train.cloud_computing_total_bytes+train.web_security_total_bytes + train.gaming_total_bytes  +train.health_total_bytes + train.communication_total_bytes +train.file_sharing_total_bytes+train.remote_access_total_bytes +train.photo_sharing_total_bytes +train.software_dwnld_total_bytes +train.marketplace_total_bytes +train.storage_services_total_bytes+train.audio_total_bytes +train.location_services_total_bytes +train.presence_total_bytes  +train.advertisement_total_bytes +train.system_total_bytes +train.voip_total_bytes +train.speedtest_total_bytes +train.speedtest_total_bytes +train.email_total_bytes +train.weather_total_bytes +train.media_total_bytes +train.mms_total_bytes +train.others_total_bytes

# %%
rs = np.random.RandomState(0)
corr = train.corr()
corr.style.background_gradient().set_precision(3)
# Out:
# <style  type="text/css" >
#     #T_fd31c2ee_24a6_11e9_ab82_0242ac1c0002row0_col0 {
#             background-color:  #023858;
#         }    #T_fd31c2ee_24a6_11e9_ab82_0242ac1c0002row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_fd31c2ee_24a6_11e9_ab82_0242ac1c0002row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_fd31c2ee_24a6_11e9_ab82_0242ac1c0002row0_col3 {
#             background-color:  #fdf5fa;
#         }    #T_fd31c2ee_24a6_11e9_ab82_0242ac1c0002row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_fd31c2ee_24a6_11e9_ab82_0242ac1c0002row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_fd31c2ee_24a6_11e9_ab82_0242ac1c0002row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_fd31c2ee_24a6_11e9_ab82_0242ac1c0002row0_col7 {
#             background-color:  #fff7fb;
#         }    #T_fd31c2ee_24a6_11e9_ab82_0242ac1c0002row0_col8 {
#             background-color:  #fdf5fa;
# ...

# %%
#train.to_csv(r'Rmai.csv')
#from google.colab import files
#files.download("Rmai.csv")

# %%
import seaborn as sns

sns.set(style="white")

######################



######################



# Compute the correlation matrix
corr = train.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
train['Total_bytes']=train.web_browsing_total_bytes + train.video_total_bytes + train.social_ntwrking_bytes + train.cloud_computing_total_bytes+train.web_security_total_bytes + train.gaming_total_bytes  +train.health_total_bytes + train.communication_total_bytes +train.file_sharing_total_bytes+train.remote_access_total_bytes +train.photo_sharing_total_bytes +train.software_dwnld_total_bytes +train.marketplace_total_bytes +train.storage_services_total_bytes+train.audio_total_bytes +train.location_services_total_bytes +train.presence_total_bytes  +train.advertisement_total_bytes +train.system_total_bytes +train.voip_total_bytes +train.speedtest_total_bytes +train.speedtest_total_bytes +train.email_total_bytes +train.weather_total_bytes +train.media_total_bytes +train.mms_total_bytes +train.others_total_bytes

# %%
train['Total_bytes']

# %%
import seaborn as sns

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
  
 
  
# dataframe created with 
# the above data array 
df = pd.DataFrame(train, columns = ['web_browsing_total_bytes', 'Congestion_Type','c.	social_ntwrking_bytes'] ) 
  
# create histogram for numeric data 
df.hist() 
  
# show plot 
plt.show()

# %%
plt.scatter(train['web_browsing_total_bytes'], train['Congestion_Type']) 
plt.xlabel('web_browsing_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['video_total_bytes'], train['Congestion_Type']) 
plt.xlabel('video_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['social_ntwrking_bytes'], train['Congestion_Type']) 
plt.xlabel('social_ntwrking_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['cloud_computing_total_bytes'], train['Congestion_Type']) 
plt.xlabel('cloud_computing_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['web_security_total_bytes'], train['Congestion_Type']) 
plt.xlabel('web_security_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['gaming_total_bytes'], train['Congestion_Type']) 
plt.xlabel('gaming_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['health_total_bytes'], train['Congestion_Type']) 
plt.xlabel('health_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['communication_total_bytes'], train['Congestion_Type']) 
plt.xlabel('communication_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['file_sharing_total_bytes'], train['Congestion_Type'])
plt.xlabel('file_sharing_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['remote_access_total_bytes'], train['Congestion_Type']) 
plt.xlabel('remote_access_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['photo_sharing_total_bytes'], train['Congestion_Type']) 
plt.xlabel('photo_sharing_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['software_dwnld_total_bytes'], train['Congestion_Type']) 
plt.xlabel('software_dwnld_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['marketplace_total_bytes'], train['Congestion_Type']) 
plt.xlabel('marketplace_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['storage_services_total_bytes'], train['Congestion_Type']) 
plt.xlabel('storage_services_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['audio_total_bytes'], train['Congestion_Type']) 
plt.xlabel('audio_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['location_services_total_bytes'], train['Congestion_Type']) 
plt.xlabel('location_services_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['presence_total_bytes'], train['Congestion_Type']) 
plt.xlabel('presence_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['advertisement_total_bytes'], train['Congestion_Type']) 
plt.xlabel('advertisement_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['system_total_bytes'], train['Congestion_Type']) 
plt.xlabel('system_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['voip_total_bytes'], train['Congestion_Type']) 
plt.xlabel('voip_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['speedtest_total_bytes'], train['Congestion_Type']) 
plt.xlabel('speedtest_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['email_total_bytes'], train['Congestion_Type']) 
plt.xlabel('email_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['weather_total_bytes'], train['Congestion_Type']) 
plt.xlabel('weather_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['media_total_bytes'], train['Congestion_Type']) 
plt.xlabel('media_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['mms_total_bytes'], train['Congestion_Type']) 
plt.xlabel('mms_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['others_total_bytes'], train['Congestion_Type']) 
plt.xlabel('others_total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
plt.scatter(train['Total_bytes'], train['Congestion_Type']) 
plt.xlabel('Total_bytes')
plt.ylabel('Congestion_Type')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

#x1 = train[["web_browsing_total_bytes", "video_total_bytes", "social_ntwrking_bytes", "cloud_computing_total_bytes","web_security_total_bytes","gaming_total_bytes","communication_total_bytes","file_sharing_total_bytes","remote_access_total_bytes","photo_sharing_total_bytes","software_dwnld_total_bytes","marketplace_total_bytes","storage_services_total_bytes","audio_total_bytes","location_services_total_bytes","presence_total_bytes","advertisement_total_bytes","system_total_bytes","voip_total_bytes","speedtest_total_bytes","speedtest_total_bytes","email_total_bytes","weather_total_bytes","media_total_bytes","mms_total_bytes","others_total_bytes"]]
#y1 = train['Congestion_Type']==0



##################################################### 


a= np.asarray(train['Congestion_Type'])
b= np.asarray(train['cloud_computing_total_bytes'])
#print(a)

dataset = pd.DataFrame({'a': a, 'b': list(b)}, columns=['a', 'b'])

# %%
k1=train.groupby('Congestion_Type')['web_browsing_total_bytes'].describe()
k2=train.groupby('Congestion_Type')['video_total_bytes'].describe()
k3=train.groupby('Congestion_Type')['social_ntwrking_bytes'].describe()
k4=train.groupby('Congestion_Type')['cloud_computing_total_bytes'].describe()
k5=train.groupby('Congestion_Type')['web_security_total_bytes'].describe()
k6=train.groupby('Congestion_Type')['gaming_total_bytes'].describe()
k7=train.groupby('Congestion_Type')['health_total_bytes'].describe()
k8=train.groupby('Congestion_Type')['communication_total_bytes'].describe()
k9=train.groupby('Congestion_Type')['file_sharing_total_bytes'].describe()
k10=train.groupby('Congestion_Type')['remote_access_total_bytes'].describe()
k11=train.groupby('Congestion_Type')['photo_sharing_total_bytes'].describe()
k12=train.groupby('Congestion_Type')['software_dwnld_total_bytes'].describe()
k13=train.groupby('Congestion_Type')['marketplace_total_bytes'].describe()
k14=train.groupby('Congestion_Type')['storage_services_total_bytes'].describe()
k15=train.groupby('Congestion_Type')['audio_total_bytes'].describe()
k16=train.groupby('Congestion_Type')['location_services_total_bytes'].describe()
k17=train.groupby('Congestion_Type')['presence_total_bytes'].describe()
k18=train.groupby('Congestion_Type')['advertisement_total_bytes'].describe()
k19=train.groupby('Congestion_Type')['system_total_bytes'].describe()
k20=train.groupby('Congestion_Type')['voip_total_bytes'].describe()
k21=train.groupby('Congestion_Type')['speedtest_total_bytes'].describe()
k22=train.groupby('Congestion_Type')['email_total_bytes'].describe()
k23=train.groupby('Congestion_Type')['weather_total_bytes'].describe()
k24=train.groupby('Congestion_Type')['media_total_bytes'].describe()
k25=train.groupby('Congestion_Type')['mms_total_bytes'].describe()
k26=train.groupby('Congestion_Type')['others_total_bytes'].describe()
k27=train.groupby('Congestion_Type')['Total_bytes'].describe()

# %%
k=k1.append([k2,k3,k4,k5,k6,k7,k8,k9,k10,k11,k12,k13,k14,k15,k16,k17,k18,k19,k20,k21,k22,k23,k24,k25,k26,k27])

# %%
print(k)

# %%
k.to_csv(r'Rmai.csv')
from google.colab import files
files.download("Rmai.csv")
